# %%
from Text2Image import *

# %%
generator = ImageGenerator()

# %%
prompt = "a person fishing on boat"

image = generator.run(prompt)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=768x768 at 0x7F3D546E96D0>
